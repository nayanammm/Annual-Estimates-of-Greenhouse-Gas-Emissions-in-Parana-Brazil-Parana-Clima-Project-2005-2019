# %% [markdown]
# <a href="https://colab.research.google.com/github/nayanammm/Annual-Estimates-of-Greenhouse-Gas-Emissions-in-Parana-Brazil-Parana-Clima-Project-2005-2019/blob/main/SUBSETOR_3_A_FERMENTA%C3%87%C3%83O_ENTT%C3%89RICA_%2B_3B_MANEJO_DE_DEJETOS_2005_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import folium
import folium.plugins as plugins

# %% [markdown]
# ## Abrir csv com os dados de todos os rebanhos dos municípios do dropbox
#
# Dados de rebanhos obtidos no site do IPARDES anos 2005 até 2019 << http://www.ipardes.gov.br/imp/index.php >>

# %%
REBANHO_TODOS_ANO_TODOS = pd.read_csv('https://www.dropbox.com/s/o00mya5qx70rhzp/AFOLU_rebanhos_todos_2005_2019.csv?dl=1')
REBANHO_TODOS_ANO_TODOS.head()
# Out:
#       mun   Ano  CORTE  EQUINO  ...  MUARES  OVINOS  ASININOS  VACAS
# 0  Abatiá  2005  17933     850  ...     482     349         1   2860
# 1  Abatiá  2006  16663     847  ...     481     354         1   2127
# 2  Abatiá  2007  14486     799  ...     480     360         0   2150
# 3  Abatiá  2008  16222     802  ...     485     363         0   2407
# 4  Abatiá  2009  19203     803  ...     483     359         0   2688
#
# [5 rows x 13 columns]

# %%
REBANHO_TODOS_ANO_TODOS = REBANHO_TODOS_ANO_TODOS.set_index('mun')

# %%
REBANHO_TODOS_ANO_TODOS.head()
# Out:
#          Ano  CORTE  EQUINO  GALINACEOS  ...  MUARES  OVINOS  ASININOS  VACAS
# mun                                      ...
# Abatiá  2005  17933     850       38600  ...     482     349         1   2860
# Abatiá  2006  16663     847       38585  ...     481     354         1   2127
# Abatiá  2007  14486     799       38700  ...     480     360         0   2150
# Abatiá  2008  16222     802       38642  ...     485     363         0   2407
# Abatiá  2009  19203     803       38750  ...     483     359         0   2688
#
# [5 rows x 12 columns]

# %%
REBANHO_TODOS_ANO_TODOS.shape
# Out:
# (5985, 12)

# %%
## Somatório de cabeças acumulados para o período entre 2005-2019 em todos os municípios
REBANHO_TODOS_ANO_TODOS.sum()
# Out:
# Ano             12041820
# CORTE          141858351
# EQUINO           5048625
# GALINACEOS    4214198379
# CODORNAS         9654445
# SUINOS          86138790
# BUBALINOS         453280
# CAPRINOS         2227766
# MUARES            363629
# OVINOS           8848940
# ASININOS           17651
# VACAS           22437455
# dtype: int64

# %% [markdown]
# ## Abrir lista códigos IBGE dos municípios

# %%
cdibge = pd.read_csv('https://www.dropbox.com/s/khnf2k1eyeqa1av/IBGE_cd_mun.csv?dl=1')
cdibge.head()
# Out:
#         cd                  mun
# 0  4100103               Abatiá
# 1  4100202         Adrianópolis
# 2  4100301        Agudos do Sul
# 3  4100400  Almirante Tamandaré
# 4  4100459   Altamira do Paraná

# %%
cdibge = cdibge.set_index('mun')

# %%
REBANHO_TODOS_ANO_TODOS = pd.merge(cdibge,REBANHO_TODOS_ANO_TODOS, on='mun', how='left')

# %%
REBANHO_TODOS_ANO_TODOS
# Out:
#              cd   Ano  CORTE  EQUINO  ...  MUARES  OVINOS  ASININOS  VACAS
# mun                                   ...
# Abatiá  4100103  2005  17933     850  ...     482     349         1   2860
# Abatiá  4100103  2006  16663     847  ...     481     354         1   2127
# Abatiá  4100103  2007  14486     799  ...     480     360         0   2150
# Abatiá  4100103  2008  16222     802  ...     485     363         0   2407
# Abatiá  4100103  2009  19203     803  ...     483     359         0   2688
# ...         ...   ...    ...     ...  ...     ...     ...       ...    ...
# Xambrê  4128807  2015  48187     781  ...       0     705         0   3982
# Xambrê  4128807  2016  52280     716  ...       0     701         0   3642
# Xambrê  4128807  2017  48700     740  ...       0     600         0   3475
# Xambrê  4128807  2018  49431     770  ...       0     620         0   4385
# Xambrê  4128807  2019  45031     800  ...       0     800         0   4658
#
# [5985 rows x 13 columns]

# %%
##REBANHO_TODOS_ANO_TODOS = REBANHO_TODOS_ANO_TODOS.set_index('cd')

# %%
REBANHO_TODOS_ANO_TODOS['CORTE'] = REBANHO_TODOS_ANO_TODOS['CORTE'] - REBANHO_TODOS_ANO_TODOS['VACAS']
REBANHO_TODOS_ANO_TODOS['AVES'] = REBANHO_TODOS_ANO_TODOS['GALINACEOS'] + REBANHO_TODOS_ANO_TODOS['CODORNAS']

# %%
REBANHO_TODOS_ANO_TODOS
# Out:
#              cd   Ano  CORTE  EQUINO  ...  OVINOS  ASININOS  VACAS    AVES
# mun                                   ...
# Abatiá  4100103  2005  15073     850  ...     349         1   2860   38600
# Abatiá  4100103  2006  14536     847  ...     354         1   2127   38585
# Abatiá  4100103  2007  12336     799  ...     360         0   2150   38700
# Abatiá  4100103  2008  13815     802  ...     363         0   2407   38642
# Abatiá  4100103  2009  16515     803  ...     359         0   2688   38750
# ...         ...   ...    ...     ...  ...     ...       ...    ...     ...
# Xambrê  4128807  2015  44205     781  ...     705         0   3982  379400
# Xambrê  4128807  2016  48638     716  ...     701         0   3642  200546
# Xambrê  4128807  2017  45225     740  ...     600         0   3475  181500
# Xambrê  4128807  2018  45046     770  ...     620         0   4385  172000
# Xambrê  4128807  2019  40373     800  ...     800         0   4658  110068
#
# [5985 rows x 14 columns]

# %%
REBANHO_TODOS_ANO_TODOS.sum()
# Out:
# cd            24624902190
# Ano              12041820
# CORTE           119420896
# EQUINO            5048625
# GALINACEOS     4214198379
# CODORNAS          9654445
# SUINOS           86138790
# BUBALINOS          453280
# CAPRINOS          2227766
# MUARES             363629
# OVINOS            8848940
# ASININOS            17651
# VACAS            22437455
# AVES           4223852824
# dtype: int64

# %% [markdown]
# ##EMISSÕES FERMENTAÇÃO ENTÉRICA ANUAIS 2005 - 2019

# %%
REBANHO_TODOS_ANO_TODOS = REBANHO_TODOS_ANO_TODOS.set_index('cd')

# %%
REBANHO_TODOS_ANO_TODOS
# Out:
#           Ano  CORTE  EQUINO  GALINACEOS  ...  OVINOS  ASININOS  VACAS    AVES
# cd                                        ...
# 4100103  2005  15073     850       38600  ...     349         1   2860   38600
# 4100103  2006  14536     847       38585  ...     354         1   2127   38585
# 4100103  2007  12336     799       38700  ...     360         0   2150   38700
# 4100103  2008  13815     802       38642  ...     363         0   2407   38642
# 4100103  2009  16515     803       38750  ...     359         0   2688   38750
# ...       ...    ...     ...         ...  ...     ...       ...    ...     ...
# 4128807  2015  44205     781      379400  ...     705         0   3982  379400
# 4128807  2016  48638     716      200546  ...     701         0   3642  200546
# 4128807  2017  45225     740      181500  ...     600         0   3475  181500
# 4128807  2018  45046     770      172000  ...     620         0   4385  172000
# ...

# %%
REBANHO_2005 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2005]

REBANHO_2005['EM_F.ENT_corte_GgCH4/municipio/2005'] = REBANHO_2005['CORTE'] * 49.68 * 0.000001
REBANHO_2005['EM_F.ENT_leiteira_GgCH4/municipio/2005'] = REBANHO_2005['VACAS'] * 96.12 * 0.000001
REBANHO_2005['EM_F.ENT_equino_GgCH4/municipio/2005'] = REBANHO_2005['EQUINO'] * 18 * 0.000001
REBANHO_2005['EM_F.ENT_suino_GgCH4/municipio/2005'] = REBANHO_2005['SUINOS'] * 1 * 0.000001
REBANHO_2005['EM_F.ENT_bubalino_GgCH4/municipio/2005'] = REBANHO_2005['BUBALINOS'] * 55 * 0.000001
REBANHO_2005['EM_F.ENT_caprino_GgCH4/municipio/2005'] = REBANHO_2005['CAPRINOS'] * 5 * 0.000001
REBANHO_2005['EM_F.ENT_muar_GgCH4/municipio/2005'] = REBANHO_2005['MUARES'] * 10 * 0.000001
REBANHO_2005['EM_F.ENT_ovino_GgCH4/municipio/2005'] = REBANHO_2005['OVINOS'] * 5 * 0.000001
REBANHO_2005['EM_F.ENT_asinino_GgCH4/municipio/2005'] = REBANHO_2005['ASININOS'] * 10 * 0.000001

REBANHO_2005
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2006 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2006]

REBANHO_2006['EM_F.ENT_corte_GgCH4/municipio/2006'] = REBANHO_2006['CORTE'] * 49.81 * 0.000001
REBANHO_2006['EM_F.ENT_leiteira_GgCH4/municipio/2006'] = REBANHO_2006['VACAS'] * 96 * 0.000001
REBANHO_2006['EM_F.ENT_equino_GgCH4/municipio/2006'] = REBANHO_2006['EQUINO'] * 18 * 0.000001
REBANHO_2006['EM_F.ENT_suino_GgCH4/municipio/2006'] = REBANHO_2006['SUINOS'] * 1 * 0.000001
REBANHO_2006['EM_F.ENT_bubalino_GgCH4/municipio/2006'] = REBANHO_2006['BUBALINOS'] * 55 * 0.000001
REBANHO_2006['EM_F.ENT_caprino_GgCH4/municipio/2006'] = REBANHO_2006['CAPRINOS'] * 5 * 0.000001
REBANHO_2006['EM_F.ENT_muar_GgCH4/municipio/2006'] = REBANHO_2006['MUARES'] * 10 * 0.000001
REBANHO_2006['EM_F.ENT_ovino_GgCH4/municipio/2006'] = REBANHO_2006['OVINOS'] * 5 * 0.000001
REBANHO_2006['EM_F.ENT_asinino_GgCH4/municipio/2006'] = REBANHO_2006['ASININOS'] * 10 * 0.000001

REBANHO_2006
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2007 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2007]

REBANHO_2007['EM_F.ENT_corte_GgCH4/municipio/2007'] = REBANHO_2007['CORTE'] * 48.46 * 0.000001
REBANHO_2007['EM_F.ENT_leiteira_GgCH4/municipio/2007'] = REBANHO_2007['VACAS'] * 93.14 * 0.000001
REBANHO_2007['EM_F.ENT_equino_GgCH4/municipio/2007'] = REBANHO_2007['EQUINO'] * 18 * 0.000001
REBANHO_2007['EM_F.ENT_suino_GgCH4/municipio/2007'] = REBANHO_2007['SUINOS'] * 1 * 0.000001
REBANHO_2007['EM_F.ENT_bubalino_GgCH4/municipio/2007'] = REBANHO_2007['BUBALINOS'] * 55 * 0.000001
REBANHO_2007['EM_F.ENT_caprino_GgCH4/municipio/2007'] = REBANHO_2007['CAPRINOS'] * 5 * 0.000001
REBANHO_2007['EM_F.ENT_muar_GgCH4/municipio/2007'] = REBANHO_2007['MUARES'] * 10 * 0.000001
REBANHO_2007['EM_F.ENT_ovino_GgCH4/municipio/2007'] = REBANHO_2007['OVINOS'] * 5 * 0.000001
REBANHO_2007['EM_F.ENT_asinino_GgCH4/municipio/2007'] = REBANHO_2007['ASININOS'] * 10 * 0.000001

REBANHO_2007
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2008 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2008]

REBANHO_2008['EM_F.ENT_corte_GgCH4/municipio/2008'] = REBANHO_2008['CORTE'] * 48.83 * 0.000001
REBANHO_2008['EM_F.ENT_leiteira_GgCH4/municipio/2008'] = REBANHO_2008['VACAS'] * 93.16 * 0.000001
REBANHO_2008['EM_F.ENT_equino_GgCH4/municipio/2008'] = REBANHO_2008['EQUINO'] * 18 * 0.000001
REBANHO_2008['EM_F.ENT_suino_GgCH4/municipio/2008'] = REBANHO_2008['SUINOS'] * 1 * 0.000001
REBANHO_2008['EM_F.ENT_bubalino_GgCH4/municipio/2008'] = REBANHO_2008['BUBALINOS'] * 55 * 0.000001
REBANHO_2008['EM_F.ENT_caprino_GgCH4/municipio/2008'] = REBANHO_2008['CAPRINOS'] * 5 * 0.000001
REBANHO_2008['EM_F.ENT_muar_GgCH4/municipio/2008'] = REBANHO_2008['MUARES'] * 10 * 0.000001
REBANHO_2008['EM_F.ENT_ovino_GgCH4/municipio/2008'] = REBANHO_2008['OVINOS'] * 5 * 0.000001
REBANHO_2008['EM_F.ENT_asinino_GgCH4/municipio/2008'] = REBANHO_2008['ASININOS'] * 10 * 0.000001

REBANHO_2008
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2009 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2009]

REBANHO_2009['EM_F.ENT_corte_GgCH4/municipio/2009'] = REBANHO_2009['CORTE'] * 48.83 * 0.000001
REBANHO_2009['EM_F.ENT_leiteira_GgCH4/municipio/2009'] = REBANHO_2009['VACAS'] * 92.80 * 0.000001
REBANHO_2009['EM_F.ENT_equino_GgCH4/municipio/2009'] = REBANHO_2009['EQUINO'] * 18 * 0.000001
REBANHO_2009['EM_F.ENT_suino_GgCH4/municipio/2009'] = REBANHO_2009['SUINOS'] * 1 * 0.000001
REBANHO_2009['EM_F.ENT_bubalino_GgCH4/municipio/2009'] = REBANHO_2009['BUBALINOS'] * 55 * 0.000001
REBANHO_2009['EM_F.ENT_caprino_GgCH4/municipio/2009'] = REBANHO_2009['CAPRINOS'] * 5 * 0.000001
REBANHO_2009['EM_F.ENT_muar_GgCH4/municipio/2009'] = REBANHO_2009['MUARES'] * 10 * 0.000001
REBANHO_2009['EM_F.ENT_ovino_GgCH4/municipio/2009'] = REBANHO_2009['OVINOS'] * 5 * 0.000001
REBANHO_2009['EM_F.ENT_asinino_GgCH4/municipio/2009'] = REBANHO_2009['ASININOS'] * 10 * 0.000001

REBANHO_2009
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2010 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2010]

REBANHO_2010['EM_F.ENT_corte_GgCH4/municipio/2010'] = REBANHO_2010['CORTE'] * 48.96 * 0.000001
REBANHO_2010['EM_F.ENT_leiteira_GgCH4/municipio/2010'] = REBANHO_2010['VACAS'] * 93.85 * 0.000001
REBANHO_2010['EM_F.ENT_equino_GgCH4/municipio/2010'] = REBANHO_2010['EQUINO'] * 18 * 0.000001
REBANHO_2010['EM_F.ENT_suino_GgCH4/municipio/2010'] = REBANHO_2010['SUINOS'] * 1 * 0.000001
REBANHO_2010['EM_F.ENT_bubalino_GgCH4/municipio/2010'] = REBANHO_2010['BUBALINOS'] * 55 * 0.000001
REBANHO_2010['EM_F.ENT_caprino_GgCH4/municipio/2010'] = REBANHO_2010['CAPRINOS'] * 5 * 0.000001
REBANHO_2010['EM_F.ENT_muar_GgCH4/municipio/2010'] = REBANHO_2010['MUARES'] * 10 * 0.000001
REBANHO_2010['EM_F.ENT_ovino_GgCH4/municipio/2010'] = REBANHO_2010['OVINOS'] * 5 * 0.000001
REBANHO_2010['EM_F.ENT_asinino_GgCH4/municipio/2010'] = REBANHO_2010['ASININOS'] * 10 * 0.000001

REBANHO_2010
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2011 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2011]

REBANHO_2011['EM_F.ENT_corte_GgCH4/municipio/2011'] = REBANHO_2011['CORTE'] * 47.81 * 0.000001
REBANHO_2011['EM_F.ENT_leiteira_GgCH4/municipio/2011'] = REBANHO_2011['VACAS'] * 90.71 * 0.000001
REBANHO_2011['EM_F.ENT_equino_GgCH4/municipio/2011'] = REBANHO_2011['EQUINO'] * 18 * 0.000001
REBANHO_2011['EM_F.ENT_suino_GgCH4/municipio/2011'] = REBANHO_2011['SUINOS'] * 1 * 0.000001
REBANHO_2011['EM_F.ENT_bubalino_GgCH4/municipio/2011'] = REBANHO_2011['BUBALINOS'] * 55 * 0.000001
REBANHO_2011['EM_F.ENT_caprino_GgCH4/municipio/2011'] = REBANHO_2011['CAPRINOS'] * 5 * 0.000001
REBANHO_2011['EM_F.ENT_muar_GgCH4/municipio/2011'] = REBANHO_2011['MUARES'] * 10 * 0.000001
REBANHO_2011['EM_F.ENT_ovino_GgCH4/municipio/2011'] = REBANHO_2011['OVINOS'] * 5 * 0.000001
REBANHO_2011['EM_F.ENT_asinino_GgCH4/municipio/2011'] = REBANHO_2011['ASININOS'] * 10 * 0.000001

REBANHO_2011
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2012 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2012]

REBANHO_2012['EM_F.ENT_corte_GgCH4/municipio/2012'] = REBANHO_2012['CORTE'] * 47.44 * 0.000001
REBANHO_2012['EM_F.ENT_leiteira_GgCH4/municipio/2012'] = REBANHO_2012['VACAS'] * 90.78 * 0.000001
REBANHO_2012['EM_F.ENT_equino_GgCH4/municipio/2012'] = REBANHO_2012['EQUINO'] * 18 * 0.000001
REBANHO_2012['EM_F.ENT_suino_GgCH4/municipio/2012'] = REBANHO_2012['SUINOS'] * 1 * 0.000001
REBANHO_2012['EM_F.ENT_bubalino_GgCH4/municipio/2012'] = REBANHO_2012['BUBALINOS'] * 55 * 0.000001
REBANHO_2012['EM_F.ENT_caprino_GgCH4/municipio/2012'] = REBANHO_2012['CAPRINOS'] * 5 * 0.000001
REBANHO_2012['EM_F.ENT_muar_GgCH4/municipio/2012'] = REBANHO_2012['MUARES'] * 10 * 0.000001
REBANHO_2012['EM_F.ENT_ovino_GgCH4/municipio/2012'] = REBANHO_2012['OVINOS'] * 5 * 0.000001
REBANHO_2012['EM_F.ENT_asinino_GgCH4/municipio/2012'] = REBANHO_2012['ASININOS'] * 10 * 0.000001

REBANHO_2012
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2013 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2013]

REBANHO_2013['EM_F.ENT_corte_GgCH4/municipio/2013'] = REBANHO_2013['CORTE'] * 47.32 * 0.000001
REBANHO_2013['EM_F.ENT_leiteira_GgCH4/municipio/2013'] = REBANHO_2013['VACAS'] * 90.65 * 0.000001
REBANHO_2013['EM_F.ENT_equino_GgCH4/municipio/2013'] = REBANHO_2013['EQUINO'] * 18 * 0.000001
REBANHO_2013['EM_F.ENT_suino_GgCH4/municipio/2013'] = REBANHO_2013['SUINOS'] * 1 * 0.000001
REBANHO_2013['EM_F.ENT_bubalino_GgCH4/municipio/2013'] = REBANHO_2013['BUBALINOS'] * 55 * 0.000001
REBANHO_2013['EM_F.ENT_caprino_GgCH4/municipio/2013'] = REBANHO_2013['CAPRINOS'] * 5 * 0.000001
REBANHO_2013['EM_F.ENT_muar_GgCH4/municipio/2013'] = REBANHO_2013['MUARES'] * 10 * 0.000001
REBANHO_2013['EM_F.ENT_ovino_GgCH4/municipio/2013'] = REBANHO_2013['OVINOS'] * 5 * 0.000001
REBANHO_2013['EM_F.ENT_asinino_GgCH4/municipio/2013'] = REBANHO_2013['ASININOS'] * 10 * 0.000001

REBANHO_2013
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2014 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2014]

REBANHO_2014['EM_F.ENT_corte_GgCH4/municipio/2014'] = REBANHO_2014['CORTE'] * 47.32 * 0.000001
REBANHO_2014['EM_F.ENT_leiteira_GgCH4/municipio/2014'] = REBANHO_2014['VACAS'] * 90.69 * 0.000001
REBANHO_2014['EM_F.ENT_equino_GgCH4/municipio/2014'] = REBANHO_2014['EQUINO'] * 18 * 0.000001
REBANHO_2014['EM_F.ENT_suino_GgCH4/municipio/2014'] = REBANHO_2014['SUINOS'] * 1 * 0.000001
REBANHO_2014['EM_F.ENT_bubalino_GgCH4/municipio/2014'] = REBANHO_2014['BUBALINOS'] * 55 * 0.000001
REBANHO_2014['EM_F.ENT_caprino_GgCH4/municipio/2014'] = REBANHO_2014['CAPRINOS'] * 5 * 0.000001
REBANHO_2014['EM_F.ENT_muar_GgCH4/municipio/2014'] = REBANHO_2014['MUARES'] * 10 * 0.000001
REBANHO_2014['EM_F.ENT_ovino_GgCH4/municipio/2014'] = REBANHO_2014['OVINOS'] * 5 * 0.000001
REBANHO_2014['EM_F.ENT_asinino_GgCH4/municipio/2014'] = REBANHO_2014['ASININOS'] * 10 * 0.000001

REBANHO_2014
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2015 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2015]

REBANHO_2015['EM_F.ENT_corte_GgCH4/municipio/2015'] = REBANHO_2015['CORTE'] * 47.68 * 0.000001
REBANHO_2015['EM_F.ENT_leiteira_GgCH4/municipio/2015'] = REBANHO_2015['VACAS'] * 91.80 * 0.000001
REBANHO_2015['EM_F.ENT_equino_GgCH4/municipio/2015'] = REBANHO_2015['EQUINO'] * 18 * 0.000001
REBANHO_2015['EM_F.ENT_suino_GgCH4/municipio/2015'] = REBANHO_2015['SUINOS'] * 1 * 0.000001
REBANHO_2015['EM_F.ENT_bubalino_GgCH4/municipio/2015'] = REBANHO_2015['BUBALINOS'] * 55 * 0.000001
REBANHO_2015['EM_F.ENT_caprino_GgCH4/municipio/2015'] = REBANHO_2015['CAPRINOS'] * 5 * 0.000001
REBANHO_2015['EM_F.ENT_muar_GgCH4/municipio/2015'] = REBANHO_2015['MUARES'] * 10 * 0.000001
REBANHO_2015['EM_F.ENT_ovino_GgCH4/municipio/2015'] = REBANHO_2015['OVINOS'] * 5 * 0.000001
REBANHO_2015['EM_F.ENT_asinino_GgCH4/municipio/2015'] = REBANHO_2015['ASININOS'] * 10 * 0.000001

REBANHO_2015
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2016 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2016]

REBANHO_2016['EM_F.ENT_corte_GgCH4/municipio/2016'] = REBANHO_2016['CORTE'] * 47.68 * 0.000001
REBANHO_2016['EM_F.ENT_leiteira_GgCH4/municipio/2016'] = REBANHO_2016['VACAS'] * 92.44 * 0.000001
REBANHO_2016['EM_F.ENT_equino_GgCH4/municipio/2016'] = REBANHO_2016['EQUINO'] * 18 * 0.000001
REBANHO_2016['EM_F.ENT_suino_GgCH4/municipio/2016'] = REBANHO_2016['SUINOS'] * 1 * 0.000001
REBANHO_2016['EM_F.ENT_bubalino_GgCH4/municipio/2016'] = REBANHO_2016['BUBALINOS'] * 55 * 0.000001
REBANHO_2016['EM_F.ENT_caprino_GgCH4/municipio/2016'] = REBANHO_2016['CAPRINOS'] * 5 * 0.000001
REBANHO_2016['EM_F.ENT_muar_GgCH4/municipio/2016'] = REBANHO_2016['MUARES'] * 10 * 0.000001
REBANHO_2016['EM_F.ENT_ovino_GgCH4/municipio/2016'] = REBANHO_2016['OVINOS'] * 5 * 0.000001
REBANHO_2016['EM_F.ENT_asinino_GgCH4/municipio/2016'] = REBANHO_2016['ASININOS'] * 10 * 0.000001

REBANHO_2016
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2017 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2017]

REBANHO_2017['EM_F.ENT_corte_GgCH4/municipio/2017'] = REBANHO_2017['CORTE'] * 47.68 * 0.000001
REBANHO_2017['EM_F.ENT_leiteira_GgCH4/municipio/2017'] = REBANHO_2017['VACAS'] * 92.44 * 0.000001
REBANHO_2017['EM_F.ENT_equino_GgCH4/municipio/2017'] = REBANHO_2017['EQUINO'] * 18 * 0.000001
REBANHO_2017['EM_F.ENT_suino_GgCH4/municipio/2017'] = REBANHO_2017['SUINOS'] * 1 * 0.000001
REBANHO_2017['EM_F.ENT_bubalino_GgCH4/municipio/2017'] = REBANHO_2017['BUBALINOS'] * 55 * 0.000001
REBANHO_2017['EM_F.ENT_caprino_GgCH4/municipio/2017'] = REBANHO_2017['CAPRINOS'] * 5 * 0.000001
REBANHO_2017['EM_F.ENT_muar_GgCH4/municipio/2017'] = REBANHO_2017['MUARES'] * 10 * 0.000001
REBANHO_2017['EM_F.ENT_ovino_GgCH4/municipio/2017'] = REBANHO_2017['OVINOS'] * 5 * 0.000001
REBANHO_2017['EM_F.ENT_asinino_GgCH4/municipio/2017'] = REBANHO_2017['ASININOS'] * 10 * 0.000001

REBANHO_2017
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2018 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2018]

REBANHO_2018['EM_F.ENT_corte_GgCH4/municipio/2018'] = REBANHO_2018['CORTE'] * 47.68 * 0.000001
REBANHO_2018['EM_F.ENT_leiteira_GgCH4/municipio/2018'] = REBANHO_2018['VACAS'] * 92.44 * 0.000001
REBANHO_2018['EM_F.ENT_equino_GgCH4/municipio/2018'] = REBANHO_2018['EQUINO'] * 18 * 0.000001
REBANHO_2018['EM_F.ENT_suino_GgCH4/municipio/2018'] = REBANHO_2018['SUINOS'] * 1 * 0.000001
REBANHO_2018['EM_F.ENT_bubalino_GgCH4/municipio/2018'] = REBANHO_2018['BUBALINOS'] * 55 * 0.000001
REBANHO_2018['EM_F.ENT_caprino_GgCH4/municipio/2018'] = REBANHO_2018['CAPRINOS'] * 5 * 0.000001
REBANHO_2018['EM_F.ENT_muar_GgCH4/municipio/2018'] = REBANHO_2018['MUARES'] * 10 * 0.000001
REBANHO_2018['EM_F.ENT_ovino_GgCH4/municipio/2018'] = REBANHO_2018['OVINOS'] * 5 * 0.000001
REBANHO_2018['EM_F.ENT_asinino_GgCH4/municipio/2018'] = REBANHO_2018['ASININOS'] * 10 * 0.000001

REBANHO_2018
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2019 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2019]

REBANHO_2019['EM_F.ENT_corte_GgCH4/municipio/2019'] = REBANHO_2019['CORTE'] * 47.68 * 0.000001
REBANHO_2019['EM_F.ENT_leiteira_GgCH4/municipio/2019'] = REBANHO_2019['VACAS'] * 92.44 * 0.000001
REBANHO_2019['EM_F.ENT_equino_GgCH4/municipio/2019'] = REBANHO_2019['EQUINO'] * 18 * 0.000001
REBANHO_2019['EM_F.ENT_suino_GgCH4/municipio/2019'] = REBANHO_2019['SUINOS'] * 1 * 0.000001
REBANHO_2019['EM_F.ENT_bubalino_GgCH4/municipio/2019'] = REBANHO_2019['BUBALINOS'] * 55 * 0.000001
REBANHO_2019['EM_F.ENT_caprino_GgCH4/municipio/2019'] = REBANHO_2019['CAPRINOS'] * 5 * 0.000001
REBANHO_2019['EM_F.ENT_muar_GgCH4/municipio/2019'] = REBANHO_2019['MUARES'] * 10 * 0.000001
REBANHO_2019['EM_F.ENT_ovino_GgCH4/municipio/2019'] = REBANHO_2019['OVINOS'] * 5 * 0.000001
REBANHO_2019['EM_F.ENT_asinino_GgCH4/municipio/2019'] = REBANHO_2019['ASININOS'] * 10 * 0.000001

REBANHO_2019
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_TODOS_ANO_TODOS.describe()
# Out:
#                Ano          CORTE  ...         VACAS          AVES
# count  5985.000000    5985.000000  ...   5985.000000  5.985000e+03
# mean   2012.000000   19953.366082  ...   3748.948204  7.057398e+05
# std       4.320855   21425.272226  ...   4295.759537  1.233676e+06
# min    2005.000000      10.000000  ...      7.000000  0.000000e+00
# 25%    2008.000000    5725.000000  ...    850.000000  6.030000e+04
# 50%    2012.000000   13331.000000  ...   2380.000000  2.525000e+05
# 75%    2016.000000   26552.000000  ...   4900.000000  8.302600e+05
# max    2019.000000  190162.000000  ...  35000.000000  1.697700e+07
#
# [8 rows x 13 columns]

# %%
REBANHO_2005.sum()
# Out:
# Ano                                       7.999950e+05
# CORTE                                     8.791619e+06
# EQUINO                                    4.260040e+05
# GALINACEOS                                1.716540e+08
# CODORNAS                                  4.945060e+05
# SUINOS                                    4.547895e+06
# BUBALINOS                                 4.018700e+04
# CAPRINOS                                  1.147960e+05
# MUARES                                    5.403800e+04
# OVINOS                                    5.118010e+05
# ASININOS                                  3.025000e+03
# VACAS                                     1.361756e+06
# AVES                                      1.721485e+08
# EM_F.ENT_corte_GgCH4/municipio/2005       4.367676e+02
# EM_F.ENT_leiteira_GgCH4/municipio/2005    1.308920e+02
# EM_F.ENT_equino_GgCH4/municipio/2005      7.668072e+00
# EM_F.ENT_suino_GgCH4/municipio/2005       4.547895e+00
# ...

# %% [markdown]
# ### SUPER MERGE PARA GERAR ARQUIVO DAS EMISSÕES ANUAIS DA FERMENTAÇÃO ENTÉRICA

# %%
# compile the list of dataframes you want to merge
data_frames = [REBANHO_2005, REBANHO_2006, REBANHO_2007,REBANHO_2008,REBANHO_2009,REBANHO_2010,REBANHO_2011,REBANHO_2012,REBANHO_2013,REBANHO_2014,REBANHO_2015,REBANHO_2016,REBANHO_2017,REBANHO_2018,REBANHO_2019]

# %%
from functools import reduce

# %%
df_merged = reduce(lambda left,right: pd.merge(left,right,on=['cd'], how='outer'), data_frames)

# %%
df_merged
# Out:
#          Ano_x  ...  EM_F.ENT_asinino_GgCH4/municipio/2019
# cd              ...
# 4100103   2005  ...                                    0.0
# 4100202   2005  ...                                    0.0
# 4100301   2005  ...                                    0.0
# 4100400   2005  ...                                    0.0
# 4100459   2005  ...                                    0.0
# ...        ...  ...                                    ...
# 4128609   2005  ...                                    0.0
# 4128658   2005  ...                                    0.0
# 4128708   2005  ...                                    0.0
# 4128500   2005  ...                                    0.0
# 4128807   2005  ...                                    0.0
#
# [399 rows x 330 columns]

# %%
df_merged_reviewed = df_merged[['EM_F.ENT_corte_GgCH4/municipio/2005','EM_F.ENT_leiteira_GgCH4/municipio/2005','EM_F.ENT_equino_GgCH4/municipio/2005','EM_F.ENT_suino_GgCH4/municipio/2005','EM_F.ENT_bubalino_GgCH4/municipio/2005','EM_F.ENT_caprino_GgCH4/municipio/2005','EM_F.ENT_muar_GgCH4/municipio/2005','EM_F.ENT_ovino_GgCH4/municipio/2005','EM_F.ENT_asinino_GgCH4/municipio/2005','EM_F.ENT_corte_GgCH4/municipio/2006','EM_F.ENT_leiteira_GgCH4/municipio/2006','EM_F.ENT_equino_GgCH4/municipio/2006','EM_F.ENT_suino_GgCH4/municipio/2006','EM_F.ENT_bubalino_GgCH4/municipio/2006','EM_F.ENT_caprino_GgCH4/municipio/2006','EM_F.ENT_muar_GgCH4/municipio/2006','EM_F.ENT_ovino_GgCH4/municipio/2006','EM_F.ENT_asinino_GgCH4/municipio/2006','EM_F.ENT_corte_GgCH4/municipio/2007','EM_F.ENT_leiteira_GgCH4/municipio/2007','EM_F.ENT_equino_GgCH4/municipio/2007','EM_F.ENT_suino_GgCH4/municipio/2007','EM_F.ENT_bubalino_GgCH4/municipio/2007','EM_F.ENT_caprino_GgCH4/municipio/2007','EM_F.ENT_muar_GgCH4/municipio/2007','EM_F.ENT_ovino_GgCH4/municipio/2007','EM_F.ENT_asinino_GgCH4/municipio/2007','EM_F.ENT_corte_GgCH4/municipio/2008','EM_F.ENT_leiteira_GgCH4/municipio/2008','EM_F.ENT_equino_GgCH4/municipio/2008','EM_F.ENT_suino_GgCH4/municipio/2008','EM_F.ENT_bubalino_GgCH4/municipio/2008','EM_F.ENT_caprino_GgCH4/municipio/2008','EM_F.ENT_muar_GgCH4/municipio/2008','EM_F.ENT_ovino_GgCH4/municipio/2008','EM_F.ENT_asinino_GgCH4/municipio/2008','EM_F.ENT_corte_GgCH4/municipio/2009','EM_F.ENT_leiteira_GgCH4/municipio/2009','EM_F.ENT_equino_GgCH4/municipio/2009','EM_F.ENT_suino_GgCH4/municipio/2009','EM_F.ENT_bubalino_GgCH4/municipio/2009','EM_F.ENT_caprino_GgCH4/municipio/2009','EM_F.ENT_muar_GgCH4/municipio/2009','EM_F.ENT_ovino_GgCH4/municipio/2009','EM_F.ENT_asinino_GgCH4/municipio/2009','EM_F.ENT_corte_GgCH4/municipio/2010','EM_F.ENT_leiteira_GgCH4/municipio/2010','EM_F.ENT_equino_GgCH4/municipio/2010','EM_F.ENT_suino_GgCH4/municipio/2010','EM_F.ENT_bubalino_GgCH4/municipio/2010','EM_F.ENT_caprino_GgCH4/municipio/2010','EM_F.ENT_muar_GgCH4/municipio/2010','EM_F.ENT_ovino_GgCH4/municipio/2010','EM_F.ENT_asinino_GgCH4/municipio/2010','EM_F.ENT_corte_GgCH4/municipio/2011','EM_F.ENT_leiteira_GgCH4/municipio/2011','EM_F.ENT_equino_GgCH4/municipio/2011','EM_F.ENT_suino_GgCH4/municipio/2011','EM_F.ENT_bubalino_GgCH4/municipio/2011','EM_F.ENT_caprino_GgCH4/municipio/2011','EM_F.ENT_muar_GgCH4/municipio/2011','EM_F.ENT_ovino_GgCH4/municipio/2011','EM_F.ENT_asinino_GgCH4/municipio/2011','EM_F.ENT_corte_GgCH4/municipio/2012','EM_F.ENT_leiteira_GgCH4/municipio/2012','EM_F.ENT_equino_GgCH4/municipio/2012','EM_F.ENT_suino_GgCH4/municipio/2012','EM_F.ENT_bubalino_GgCH4/municipio/2012','EM_F.ENT_caprino_GgCH4/municipio/2012','EM_F.ENT_muar_GgCH4/municipio/2012','EM_F.ENT_ovino_GgCH4/municipio/2012','EM_F.ENT_asinino_GgCH4/municipio/2012','EM_F.ENT_corte_GgCH4/municipio/2013','EM_F.ENT_leiteira_GgCH4/municipio/2013','EM_F.ENT_equino_GgCH4/municipio/2013','EM_F.ENT_suino_GgCH4/municipio/2013','EM_F.ENT_bubalino_GgCH4/municipio/2013','EM_F.ENT_caprino_GgCH4/municipio/2013','EM_F.ENT_muar_GgCH4/municipio/2013','EM_F.ENT_ovino_GgCH4/municipio/2013','EM_F.ENT_asinino_GgCH4/municipio/2013','EM_F.ENT_corte_GgCH4/municipio/2014','EM_F.ENT_leiteira_GgCH4/municipio/2014','EM_F.ENT_equino_GgCH4/municipio/2014','EM_F.ENT_suino_GgCH4/municipio/2014','EM_F.ENT_bubalino_GgCH4/municipio/2014','EM_F.ENT_caprino_GgCH4/municipio/2014','EM_F.ENT_muar_GgCH4/municipio/2014','EM_F.ENT_ovino_GgCH4/municipio/2014','EM_F.ENT_asinino_GgCH4/municipio/2014','EM_F.ENT_corte_GgCH4/municipio/2015','EM_F.ENT_leiteira_GgCH4/municipio/2015','EM_F.ENT_equino_GgCH4/municipio/2015','EM_F.ENT_suino_GgCH4/municipio/2015','EM_F.ENT_bubalino_GgCH4/municipio/2015','EM_F.ENT_caprino_GgCH4/municipio/2015','EM_F.ENT_muar_GgCH4/municipio/2015','EM_F.ENT_ovino_GgCH4/municipio/2015','EM_F.ENT_asinino_GgCH4/municipio/2015','EM_F.ENT_corte_GgCH4/municipio/2016','EM_F.ENT_leiteira_GgCH4/municipio/2016','EM_F.ENT_equino_GgCH4/municipio/2016','EM_F.ENT_suino_GgCH4/municipio/2016','EM_F.ENT_bubalino_GgCH4/municipio/2016','EM_F.ENT_caprino_GgCH4/municipio/2016','EM_F.ENT_muar_GgCH4/municipio/2016','EM_F.ENT_ovino_GgCH4/municipio/2016','EM_F.ENT_asinino_GgCH4/municipio/2016','EM_F.ENT_corte_GgCH4/municipio/2017','EM_F.ENT_leiteira_GgCH4/municipio/2017','EM_F.ENT_equino_GgCH4/municipio/2017','EM_F.ENT_suino_GgCH4/municipio/2017','EM_F.ENT_bubalino_GgCH4/municipio/2017','EM_F.ENT_caprino_GgCH4/municipio/2017','EM_F.ENT_muar_GgCH4/municipio/2017','EM_F.ENT_ovino_GgCH4/municipio/2017','EM_F.ENT_asinino_GgCH4/municipio/2017','EM_F.ENT_corte_GgCH4/municipio/2018','EM_F.ENT_leiteira_GgCH4/municipio/2018','EM_F.ENT_equino_GgCH4/municipio/2018','EM_F.ENT_suino_GgCH4/municipio/2018','EM_F.ENT_bubalino_GgCH4/municipio/2018','EM_F.ENT_caprino_GgCH4/municipio/2018','EM_F.ENT_muar_GgCH4/municipio/2018','EM_F.ENT_ovino_GgCH4/municipio/2018','EM_F.ENT_asinino_GgCH4/municipio/2018','EM_F.ENT_corte_GgCH4/municipio/2019','EM_F.ENT_leiteira_GgCH4/municipio/2019','EM_F.ENT_equino_GgCH4/municipio/2019','EM_F.ENT_suino_GgCH4/municipio/2019','EM_F.ENT_bubalino_GgCH4/municipio/2019','EM_F.ENT_caprino_GgCH4/municipio/2019','EM_F.ENT_muar_GgCH4/municipio/2019','EM_F.ENT_ovino_GgCH4/municipio/2019','EM_F.ENT_asinino_GgCH4/municipio/2019']]
df_merged_reviewed
# Out:
#          EM_F.ENT_corte_GgCH4/municipio/2005  ...  EM_F.ENT_asinino_GgCH4/municipio/2019
# cd                                            ...
# 4100103                             0.748827  ...                                    0.0
# 4100202                             0.771928  ...                                    0.0
# 4100301                             0.081475  ...                                    0.0
# 4100400                             0.046848  ...                                    0.0
# 4100459                             2.384839  ...                                    0.0
# ...                                      ...  ...                                    ...
# 4128609                             0.980137  ...                                    0.0
# 4128658                             0.374985  ...                                    0.0
# 4128708                             0.524273  ...                                    0.0
# ...

# %%
### adicionando coluna de somatório de emissão de todos os rebanhos por ano 
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2005'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2005'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2005'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2005'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2005'] 
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2006'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2006'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2006'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2006'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2006']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2007'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2007'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2007'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2007'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2007']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2008'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2008'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2008'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2008'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2008']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2009'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2009'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2009'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2009'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2009']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2010'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2010'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2010'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2010'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2010']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2011'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2011'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2011'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2011'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2011']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2012'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2012'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2012'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2012'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2012']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2013'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2013'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2013'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2013'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2013']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2014'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2014'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2014'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2014'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2014']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2015'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2015'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2015'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2015'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2015']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2016'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2016'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2016'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2016'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2016']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2017'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2017'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2017'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2017'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2017']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2018'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2018'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2018'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2018'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2018']
df_merged_reviewed['EM_F.ENT_todos_GgCH4/municipio/2019'] = df_merged_reviewed['EM_F.ENT_corte_GgCH4/municipio/2019'] + df_merged_reviewed['EM_F.ENT_leiteira_GgCH4/municipio/2019'] + df_merged_reviewed['EM_F.ENT_equino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_F.ENT_suino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_F.ENT_bubalino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_F.ENT_caprino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_F.ENT_muar_GgCH4/municipio/2019'] + df_merged_reviewed['EM_F.ENT_ovino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_F.ENT_asinino_GgCH4/municipio/2019']

df_merged_reviewed
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_merged_reviewed.describe()
# Out:
#        EM_F.ENT_corte_GgCH4/municipio/2005  ...  EM_F.ENT_todos_GgCH4/municipio/2019
# count                           399.000000  ...                           399.000000
# mean                              1.094656  ...                             1.261927
# std                               1.108734  ...                             1.289373
# min                               0.001242  ...                             0.004078
# 25%                               0.370812  ...                             0.358983
# 50%                               0.771232  ...                             0.815527
# 75%                               1.427282  ...                             1.779339
# max                               9.447248  ...                             8.048540
#
# [8 rows x 150 columns]

# %%
df_merged_reviewed.sum()
# Out:
# EM_F.ENT_corte_GgCH4/municipio/2005       436.767632
# EM_F.ENT_leiteira_GgCH4/municipio/2005    130.891987
# EM_F.ENT_equino_GgCH4/municipio/2005        7.668072
# EM_F.ENT_suino_GgCH4/municipio/2005         4.547895
# EM_F.ENT_bubalino_GgCH4/municipio/2005      2.210285
#                                              ...
# EM_F.ENT_todos_GgCH4/municipio/2015       534.447514
# EM_F.ENT_todos_GgCH4/municipio/2016       541.636940
# EM_F.ENT_todos_GgCH4/municipio/2017       527.419380
# EM_F.ENT_todos_GgCH4/municipio/2018       520.109136
# EM_F.ENT_todos_GgCH4/municipio/2019       503.508911
# Length: 150, dtype: float64

# %%
cdibge = pd.read_csv('https://www.dropbox.com/s/khnf2k1eyeqa1av/IBGE_cd_mun.csv?dl=1')
cdibge.head()
# Out:
#         cd                  mun
# 0  4100103               Abatiá
# 1  4100202         Adrianópolis
# 2  4100301        Agudos do Sul
# 3  4100400  Almirante Tamandaré
# 4  4100459   Altamira do Paraná

# %%
cdibge = cdibge.set_index('cd')

# %%
df_merged_reviewed = pd.merge(cdibge,df_merged_reviewed, on='cd')

# %%
df_merged_reviewed
# Out:
#                          mun  ...  EM_F.ENT_todos_GgCH4/municipio/2019
# cd                            ...
# 4100103               Abatiá  ...                             0.819325
# 4100202         Adrianópolis  ...                             0.977995
# 4100301        Agudos do Sul  ...                             0.123258
# 4100400  Almirante Tamandaré  ...                             0.117022
# 4100459   Altamira do Paraná  ...                             3.190355
# ...                      ...  ...                                  ...
# 4128609                 Verê  ...                             1.219823
# 4128658              Virmond  ...                             0.782078
# 4128708             Vitorino  ...                             0.685024
# 4128500       Wenceslau Braz  ...                             1.004986
# 4128807               Xambrê  ...                             2.375870
#
# [399 rows x 151 columns]

# %%
from google.colab import files
df_merged_reviewed.to_csv('EMISSOES_ANUAIS_tipo_rebanho.csv', sep = ";")
files.download('EMISSOES_ANUAIS_tipo_rebanho.csv')

# %%
df_merged.sum()
# Out:
# Ano_x                                     7.999950e+05
# CORTE_x                                   8.791619e+06
# EQUINO_x                                  4.260040e+05
# GALINACEOS_x                              1.716540e+08
# CODORNAS_x                                4.945060e+05
#                                               ...
# EM_F.ENT_bubalino_GgCH4/municipio/2019    1.953490e+00
# EM_F.ENT_caprino_GgCH4/municipio/2019     5.154200e-01
# EM_F.ENT_muar_GgCH4/municipio/2019        0.000000e+00
# EM_F.ENT_ovino_GgCH4/municipio/2019       2.944980e+00
# EM_F.ENT_asinino_GgCH4/municipio/2019     0.000000e+00
# Length: 330, dtype: float64

# %%
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA = df_merged_reviewed[["mun","EM_F.ENT_todos_GgCH4/municipio/2005","EM_F.ENT_todos_GgCH4/municipio/2006","EM_F.ENT_todos_GgCH4/municipio/2007","EM_F.ENT_todos_GgCH4/municipio/2008","EM_F.ENT_todos_GgCH4/municipio/2009","EM_F.ENT_todos_GgCH4/municipio/2010","EM_F.ENT_todos_GgCH4/municipio/2011","EM_F.ENT_todos_GgCH4/municipio/2012","EM_F.ENT_todos_GgCH4/municipio/2013","EM_F.ENT_todos_GgCH4/municipio/2014","EM_F.ENT_todos_GgCH4/municipio/2015","EM_F.ENT_todos_GgCH4/municipio/2016","EM_F.ENT_todos_GgCH4/municipio/2017","EM_F.ENT_todos_GgCH4/municipio/2018","EM_F.ENT_todos_GgCH4/municipio/2019"]]
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA
# Out:
#                          mun  ...  EM_F.ENT_todos_GgCH4/municipio/2019
# cd                            ...
# 4100103               Abatiá  ...                             0.819325
# 4100202         Adrianópolis  ...                             0.977995
# 4100301        Agudos do Sul  ...                             0.123258
# 4100400  Almirante Tamandaré  ...                             0.117022
# 4100459   Altamira do Paraná  ...                             3.190355
# ...                      ...  ...                                  ...
# 4128609                 Verê  ...                             1.219823
# 4128658              Virmond  ...                             0.782078
# 4128708             Vitorino  ...                             0.685024
# 4128500       Wenceslau Braz  ...                             1.004986
# 4128807               Xambrê  ...                             2.375870
#
# [399 rows x 16 columns]

# %% [markdown]
# ## EMISSÕES MANEJO DE DEJETOS ANUAIS 2005 - 2019
#
# Com base nos fatores de emissão do 4º inventário nacional.
#
# << https://docs.google.com/spreadsheets/d/1pkdQHNlzVSPWtz_Ytxuw14KuHzpx-cq_EErrPDKHwq8/edit?usp=sharing>>

# %%
REBANHO_TODOS_ANO_TODOS = pd.read_csv('https://www.dropbox.com/s/o00mya5qx70rhzp/AFOLU_rebanhos_todos_2005_2019.csv?dl=1')
REBANHO_TODOS_ANO_TODOS.head()
# Out:
#       mun   Ano  CORTE  EQUINO  ...  MUARES  OVINOS  ASININOS  VACAS
# 0  Abatiá  2005  17933     850  ...     482     349         1   2860
# 1  Abatiá  2006  16663     847  ...     481     354         1   2127
# 2  Abatiá  2007  14486     799  ...     480     360         0   2150
# 3  Abatiá  2008  16222     802  ...     485     363         0   2407
# 4  Abatiá  2009  19203     803  ...     483     359         0   2688
#
# [5 rows x 13 columns]

# %%
#REBANHO_TODOS_ANO_TODOS = REBANHO_TODOS_ANO_TODOS.set_index('cd')
REBANHO_TODOS_ANO_TODOS
# Out:
#          mun   Ano  CORTE  EQUINO  ...  MUARES  OVINOS  ASININOS  VACAS
# 0     Abatiá  2005  17933     850  ...     482     349         1   2860
# 1     Abatiá  2006  16663     847  ...     481     354         1   2127
# 2     Abatiá  2007  14486     799  ...     480     360         0   2150
# 3     Abatiá  2008  16222     802  ...     485     363         0   2407
# 4     Abatiá  2009  19203     803  ...     483     359         0   2688
# ...      ...   ...    ...     ...  ...     ...     ...       ...    ...
# 5980  Xambrê  2015  48187     781  ...       0     705         0   3982
# 5981  Xambrê  2016  52280     716  ...       0     701         0   3642
# 5982  Xambrê  2017  48700     740  ...       0     600         0   3475
# 5983  Xambrê  2018  49431     770  ...       0     620         0   4385
# 5984  Xambrê  2019  45031     800  ...       0     800         0   4658
#
# [5985 rows x 13 columns]

# %%
## BOVINO DE CORTE CONFINADO 

REBANHO_2005 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2005]


## BOVINO DE CORTE CONFINADO 
Nrate_corte_conf = 102.2
TAM_corte_conf = 358
NEX_corte_conf = Nrate_corte_conf * TAM_corte_conf * 10**-3

solid_storage_corte_conf = 0.92

dry_lot_corte_conf = 0.07

biodigestor_corte_conf = 0.01

#PR:
#NEMMS_solid_storage_corte_conf = 345620.8850 * NEX_corte_conf * solid_storage_corte_conf
#NEMMS_dry_lot_corte_conf = 345620.8850 * NEX_corte_conf * dry_lot_corte_conf
#NEMMS_biodigestor_corte_conf = 345620.8850 * NEX_corte_conf * biodigestor_corte_conf


NEMMS_dry_lot_corte_conf = REBANHO_2005['CORTE'] * NEX_corte_conf * solid_storage_corte_conf
NEMMS_dry_lot_corte_conf = REBANHO_2005['CORTE'] * NEX_corte_conf * dry_lot_corte_conf
NEMMS_biodigestor_corte_conf = REBANHO_2005['CORTE'] * NEX_corte_conf * biodigestor_corte_conf

EF3_solid_storage = 0.01
EF3_dry_lot = 0.02
EF3_biodigestor = 0.00


N2OD_SS_KG_N2O = NEMMS_solid_storage_corte_conf * EF3_solid_storage * 1.57
N2OD_DL_KG_N2O = NEMMS_dry_lot_corte_conf * EF3_dry_lot * 1.57
N2OD_BIO_KG_N2O = NEMMS_biodigestor_corte_conf * EF3_biodigestor * 1.57

N2OD_TOTAL_CORTE_CONF_KG_N2O = N2OD_SS_KG_N2O + N2OD_DL_KG_N2O + N2OD_BIO_KG_N2O
N2OD_TOTAL_CORTE_CONF_ton_N2O = N2OD_TOTAL_CORTE_CONF_KG_N2O / 1000
REBANHO_2005['EM_MD_corte_conf__GgN2O_OD/municipio/2005'] = N2OD_TOTAL_CORTE_CONF_KG_N2O / 10**6
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
REBANHO_2005
# Out:
#                       mun  ...  EM_MD_corte_conf__GgN2O_OD/municipio/2005
# 0                  Abatiá  ...                                   0.184093
# 15           Adrianópolis  ...                                   0.184250
# 30          Agudos do Sul  ...                                   0.182835
# 45    Almirante Tamandaré  ...                                   0.182742
# 60     Altamira do Paraná  ...                                   0.186748
# ...                   ...  ...                                        ...
# 5910                 Verê  ...                                   0.184639
# 5925              Virmond  ...                                   0.183321
# 5940             Vitorino  ...                                   0.183813
# 5955       Wenceslau Braz  ...                                   0.184760
# 5970               Xambrê  ...                                   0.186581
#
# [399 rows x 14 columns]

# %%
N2OD_TOTAL_CORTE_CONF_KG_N2O
# Out:
# 210445.3907126967

# %%
N2OD_TOTAL_CORTE_CONF_ton_N2O
# Out:
# 210.4453907126967

# %%
N2OD_TOTAL_CORTE_CONF_Gg_N2O
# Out:
# 0.21044539071269672

# %%
NEMMS_solid_storage_corte_conf *0.01 * 1.57
# Out:
# 182650.71646762357

# %%
#2OD_SS = NEMMS_solid_storage_corte_conf * EF3_solid_storage * (44/28)
N2OD_SS
# Out:
# 182816.9136618616

# %%
N2OD_DL
# Out:
# 27819.965122457204

# %%
NEX_corte_conf
# Out:
# 36.5876

# %%
NEX_corte_conf
# Out:
# 36.5876

# %%
REBANHO_2005 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2005]


REBANHO_2005['EM_MD_corte_conf__SS_GgN2O/municipio/2005'] = NEMMS_dry_lot_corte_conf * EF3_solid_storage * (44/28)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
REBANHO_2005
# Out:
#                       mun  ...  EM_MD_corte_conf__SS_GgN2O/municipio/2005
# 0                  Abatiá  ...                                   4.113178
# 15           Adrianópolis  ...                                   4.113178
# 30          Agudos do Sul  ...                                   4.113178
# 45    Almirante Tamandaré  ...                                   4.113178
# 60     Altamira do Paraná  ...                                   4.113178
# ...                   ...  ...                                        ...
# 5910                 Verê  ...                                   4.113178
# 5925              Virmond  ...                                   4.113178
# 5940             Vitorino  ...                                   4.113178
# 5955       Wenceslau Braz  ...                                   4.113178
# 5970               Xambrê  ...                                   4.113178
#
# [399 rows x 14 columns]

# %%
REBANHO_2005 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2005]

REBANHO_2005['EM_MD_corte_GgCH4/municipio/2005'] = REBANHO_2005['CORTE'] * 1.06 * 0.000001
REBANHO_2005['EM_MD_leiteira_GgCH4/municipio/2005'] = REBANHO_2005['VACAS'] * 5.07 * 0.000001
REBANHO_2005['EM_MD_suino_GgCH4/municipio/2005'] = REBANHO_2005['SUINOS'] * 4.036 * 0.000001

REBANHO_2005['EM_MD_equino_GgCH4/municipio/2005'] = REBANHO_2005['EQUINO'] * 1.64 * 0.000001
REBANHO_2005['EM_MD_bubalino_GgCH4/municipio/2005'] = REBANHO_2005['BUBALINOS'] * 1 * 0.000001
REBANHO_2005['EM_MD_caprino_GgCH4/municipio/2005'] = REBANHO_2005['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2005['EM_MD_muar_GgCH4/municipio/2005'] = REBANHO_2005['MUARES'] * 0.9 * 0.000001
REBANHO_2005['EM_MD_ovino_GgCH4/municipio/2005'] = REBANHO_2005['OVINOS'] * 0.15 * 0.000001
REBANHO_2005['EM_MD_asinino_GgCH4/municipio/2005'] = REBANHO_2005['ASININOS'] * 0.9 * 0.000001
REBANHO_2005['EM_MD_aves_GgCH4/municipio/2005'] = REBANHO_2005['AVES'] * 0.02 * 0.000001

REBANHO_2005
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2005.sum()
# Out:
# Ano                                    7.999950e+05
# CORTE                                  8.791619e+06
# EQUINO                                 4.260040e+05
# GALINACEOS                             1.716540e+08
# CODORNAS                               4.945060e+05
# SUINOS                                 4.547895e+06
# BUBALINOS                              4.018700e+04
# CAPRINOS                               1.147960e+05
# MUARES                                 5.403800e+04
# OVINOS                                 5.118010e+05
# ASININOS                               3.025000e+03
# VACAS                                  1.361756e+06
# AVES                                   1.721485e+08
# EM_MD_corte_GgCH4/municipio/2005       9.319116e+00
# EM_MD_leiteira_GgCH4/municipio/2005    6.904103e+00
# EM_MD_suino_GgCH4/municipio/2005       1.835530e+01
# EM_MD_equino_GgCH4/municipio/2005      6.986466e-01
# EM_MD_bubalino_GgCH4/municipio/2005    4.018700e-02
# ...

# %%
REBANHO_2006 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2006]

REBANHO_2006['EM_MD_corte_GgCH4/municipio/2006'] = REBANHO_2006['CORTE'] * 1.06 * 0.000001
REBANHO_2006['EM_MD_leiteira_GgCH4/municipio/2006'] = REBANHO_2006['VACAS'] * 5.18 * 0.000001
REBANHO_2006['EM_MD_suino_GgCH4/municipio/2006'] = REBANHO_2006['SUINOS'] * 4.036 * 0.000001

REBANHO_2006['EM_MD_equino_GgCH4/municipio/2006'] = REBANHO_2006['EQUINO'] * 1.64 * 0.000001
REBANHO_2006['EM_MD_bubalino_GgCH4/municipio/2006'] = REBANHO_2006['BUBALINOS'] * 1 * 0.000001
REBANHO_2006['EM_MD_caprino_GgCH4/municipio/2006'] = REBANHO_2006['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2006['EM_MD_muar_GgCH4/municipio/2006'] = REBANHO_2006['MUARES'] * 0.9 * 0.000001
REBANHO_2006['EM_MD_ovino_GgCH4/municipio/2006'] = REBANHO_2006['OVINOS'] * 0.15 * 0.000001
REBANHO_2006['EM_MD_asinino_GgCH4/municipio/2006'] = REBANHO_2006['ASININOS'] * 0.9 * 0.000001
REBANHO_2006['EM_MD_aves_GgCH4/municipio/2006'] = REBANHO_2006['AVES'] * 0.02 * 0.000001

REBANHO_2006
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2007 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2007]

REBANHO_2007['EM_MD_corte_GgCH4/municipio/2007'] = REBANHO_2007['CORTE'] * 1.01 * 0.000001
REBANHO_2007['EM_MD_leiteira_GgCH4/municipio/2007'] = REBANHO_2007['VACAS'] * 4.99 * 0.000001
REBANHO_2007['EM_MD_suino_GgCH4/municipio/2007'] = REBANHO_2007['SUINOS'] * 4.036 * 0.000001

REBANHO_2007['EM_MD_equino_GgCH4/municipio/2007'] = REBANHO_2007['EQUINO'] * 1.64 * 0.000001
REBANHO_2007['EM_MD_bubalino_GgCH4/municipio/2007'] = REBANHO_2007['BUBALINOS'] * 1 * 0.000001
REBANHO_2007['EM_MD_caprino_GgCH4/municipio/2007'] = REBANHO_2007['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2007['EM_MD_muar_GgCH4/municipio/2007'] = REBANHO_2007['MUARES'] * 0.9 * 0.000001
REBANHO_2007['EM_MD_ovino_GgCH4/municipio/2007'] = REBANHO_2007['OVINOS'] * 0.15 * 0.000001
REBANHO_2007['EM_MD_asinino_GgCH4/municipio/2007'] = REBANHO_2007['ASININOS'] * 0.9 * 0.000001
REBANHO_2007['EM_MD_aves_GgCH4/municipio/2007'] = REBANHO_2007['AVES'] * 0.02 * 0.000001

REBANHO_2007
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2008 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2008]

REBANHO_2008['EM_MD_corte_GgCH4/municipio/2008'] = REBANHO_2008['CORTE'] * 1.01 * 0.000001
REBANHO_2008['EM_MD_leiteira_GgCH4/municipio/2008'] = REBANHO_2008['VACAS'] * 5.26 * 0.000001
REBANHO_2008['EM_MD_suino_GgCH4/municipio/2008'] = REBANHO_2008['SUINOS'] * 4.036 * 0.000001

REBANHO_2008['EM_MD_equino_GgCH4/municipio/2008'] = REBANHO_2008['EQUINO'] * 1.64 * 0.000001
REBANHO_2008['EM_MD_bubalino_GgCH4/municipio/2008'] = REBANHO_2008['BUBALINOS'] * 1 * 0.000001
REBANHO_2008['EM_MD_caprino_GgCH4/municipio/2008'] = REBANHO_2008['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2008['EM_MD_muar_GgCH4/municipio/2008'] = REBANHO_2008['MUARES'] * 0.9 * 0.000001
REBANHO_2008['EM_MD_ovino_GgCH4/municipio/2008'] = REBANHO_2008['OVINOS'] * 0.15 * 0.000001
REBANHO_2008['EM_MD_asinino_GgCH4/municipio/2008'] = REBANHO_2008['ASININOS'] * 0.9 * 0.000001
REBANHO_2008['EM_MD_aves_GgCH4/municipio/2008'] = REBANHO_2008['AVES'] * 0.02 * 0.000001

REBANHO_2008
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2009 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2009]

REBANHO_2009['EM_MD_corte_GgCH4/municipio/2009'] = REBANHO_2009['CORTE'] * 1.01 * 0.000001
REBANHO_2009['EM_MD_leiteira_GgCH4/municipio/2009'] = REBANHO_2009['VACAS'] * 5.40 * 0.000001
REBANHO_2009['EM_MD_suino_GgCH4/municipio/2009'] = REBANHO_2009['SUINOS'] * 4.036 * 0.000001

REBANHO_2009['EM_MD_equino_GgCH4/municipio/2009'] = REBANHO_2009['EQUINO'] * 1.64 * 0.000001
REBANHO_2009['EM_MD_bubalino_GgCH4/municipio/2009'] = REBANHO_2009['BUBALINOS'] * 1 * 0.000001
REBANHO_2009['EM_MD_caprino_GgCH4/municipio/2009'] = REBANHO_2009['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2009['EM_MD_muar_GgCH4/municipio/2009'] = REBANHO_2009['MUARES'] * 0.9 * 0.000001
REBANHO_2009['EM_MD_ovino_GgCH4/municipio/2009'] = REBANHO_2009['OVINOS'] * 0.15 * 0.000001
REBANHO_2009['EM_MD_asinino_GgCH4/municipio/2009'] = REBANHO_2009['ASININOS'] * 0.9 * 0.000001
REBANHO_2009['EM_MD_aves_GgCH4/municipio/2009'] = REBANHO_2009['AVES'] * 0.02 * 0.000001

REBANHO_2009
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2010 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2010]

REBANHO_2010['EM_MD_corte_GgCH4/municipio/2010'] = REBANHO_2010['CORTE'] * 1.01 * 0.000001
REBANHO_2010['EM_MD_leiteira_GgCH4/municipio/2010'] = REBANHO_2010['VACAS'] * 5.57 * 0.000001
REBANHO_2010['EM_MD_suino_GgCH4/municipio/2010'] = REBANHO_2010['SUINOS'] * 4.036 * 0.000001

REBANHO_2010['EM_MD_equino_GgCH4/municipio/2010'] = REBANHO_2010['EQUINO'] * 1.64 * 0.000001
REBANHO_2010['EM_MD_bubalino_GgCH4/municipio/2010'] = REBANHO_2010['BUBALINOS'] * 1 * 0.000001
REBANHO_2010['EM_MD_caprino_GgCH4/municipio/2010'] = REBANHO_2010['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2010['EM_MD_muar_GgCH4/municipio/2010'] = REBANHO_2010['MUARES'] * 0.9 * 0.000001
REBANHO_2010['EM_MD_ovino_GgCH4/municipio/2010'] = REBANHO_2010['OVINOS'] * 0.15 * 0.000001
REBANHO_2010['EM_MD_asinino_GgCH4/municipio/2010'] = REBANHO_2010['ASININOS'] * 0.9 * 0.000001
REBANHO_2010['EM_MD_aves_GgCH4/municipio/2010'] = REBANHO_2010['AVES'] * 0.02 * 0.000001

REBANHO_2010
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2011 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2011]

REBANHO_2011['EM_MD_corte_GgCH4/municipio/2011'] = REBANHO_2011['CORTE'] * 0.96 * 0.000001
REBANHO_2011['EM_MD_leiteira_GgCH4/municipio/2011'] = REBANHO_2011['VACAS'] * 5.28 * 0.000001
REBANHO_2011['EM_MD_suino_GgCH4/municipio/2011'] = REBANHO_2011['SUINOS'] * 6.458 * 0.000001

REBANHO_2011['EM_MD_equino_GgCH4/municipio/2011'] = REBANHO_2011['EQUINO'] * 1.64 * 0.000001
REBANHO_2011['EM_MD_bubalino_GgCH4/municipio/2011'] = REBANHO_2011['BUBALINOS'] * 1 * 0.000001
REBANHO_2011['EM_MD_caprino_GgCH4/municipio/2011'] = REBANHO_2011['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2011['EM_MD_muar_GgCH4/municipio/2011'] = REBANHO_2011['MUARES'] * 0.9 * 0.000001
REBANHO_2011['EM_MD_ovino_GgCH4/municipio/2011'] = REBANHO_2011['OVINOS'] * 0.15 * 0.000001
REBANHO_2011['EM_MD_asinino_GgCH4/municipio/2011'] = REBANHO_2011['ASININOS'] * 0.9 * 0.000001
REBANHO_2011['EM_MD_aves_GgCH4/municipio/2011'] = REBANHO_2011['AVES'] * 0.02 * 0.000001

REBANHO_2011
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2012 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2012]

REBANHO_2012['EM_MD_corte_GgCH4/municipio/2012'] = REBANHO_2012['CORTE'] * 0.94 * 0.000001
REBANHO_2012['EM_MD_leiteira_GgCH4/municipio/2012'] = REBANHO_2012['VACAS'] * 5.49 * 0.000001
REBANHO_2012['EM_MD_suino_GgCH4/municipio/2012'] = REBANHO_2012['SUINOS'] * 6.654 * 0.000001

REBANHO_2012['EM_MD_equino_GgCH4/municipio/2012'] = REBANHO_2012['EQUINO'] * 1.64 * 0.000001
REBANHO_2012['EM_MD_bubalino_GgCH4/municipio/2012'] = REBANHO_2012['BUBALINOS'] * 1 * 0.000001
REBANHO_2012['EM_MD_caprino_GgCH4/municipio/2012'] = REBANHO_2012['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2012['EM_MD_muar_GgCH4/municipio/2012'] = REBANHO_2012['MUARES'] * 0.9 * 0.000001
REBANHO_2012['EM_MD_ovino_GgCH4/municipio/2012'] = REBANHO_2012['OVINOS'] * 0.15 * 0.000001
REBANHO_2012['EM_MD_asinino_GgCH4/municipio/2012'] = REBANHO_2012['ASININOS'] * 0.9 * 0.000001
REBANHO_2012['EM_MD_aves_GgCH4/municipio/2012'] = REBANHO_2012['AVES'] * 0.02 * 0.000001

REBANHO_2012
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2013 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2013]

REBANHO_2013['EM_MD_corte_GgCH4/municipio/2013'] = REBANHO_2013['CORTE'] * 0.94 * 0.000001
REBANHO_2013['EM_MD_leiteira_GgCH4/municipio/2013'] = REBANHO_2013['VACAS'] * 5.78 * 0.000001
REBANHO_2013['EM_MD_suino_GgCH4/municipio/2013'] = REBANHO_2013['SUINOS'] * 6.446 * 0.000001

REBANHO_2013['EM_MD_equino_GgCH4/municipio/2013'] = REBANHO_2013['EQUINO'] * 1.64 * 0.000001
REBANHO_2013['EM_MD_bubalino_GgCH4/municipio/2013'] = REBANHO_2013['BUBALINOS'] * 1 * 0.000001
REBANHO_2013['EM_MD_caprino_GgCH4/municipio/2013'] = REBANHO_2013['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2013['EM_MD_muar_GgCH4/municipio/2013'] = REBANHO_2013['MUARES'] * 0.9 * 0.000001
REBANHO_2013['EM_MD_ovino_GgCH4/municipio/2013'] = REBANHO_2013['OVINOS'] * 0.15 * 0.000001
REBANHO_2013['EM_MD_asinino_GgCH4/municipio/2013'] = REBANHO_2013['ASININOS'] * 0.9 * 0.000001
REBANHO_2013['EM_MD_aves_GgCH4/municipio/2013'] = REBANHO_2013['AVES'] * 0.02 * 0.000001

REBANHO_2013
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2014 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2014]

REBANHO_2014['EM_MD_corte_GgCH4/municipio/2014'] = REBANHO_2014['CORTE'] * 0.94 * 0.000001
REBANHO_2014['EM_MD_leiteira_GgCH4/municipio/2014'] = REBANHO_2014['VACAS'] * 5.99 * 0.000001
REBANHO_2014['EM_MD_suino_GgCH4/municipio/2014'] = REBANHO_2014['SUINOS'] * 6.596 * 0.000001

REBANHO_2014['EM_MD_equino_GgCH4/municipio/2014'] = REBANHO_2014['EQUINO'] * 1.64 * 0.000001
REBANHO_2014['EM_MD_bubalino_GgCH4/municipio/2014'] = REBANHO_2014['BUBALINOS'] * 1 * 0.000001
REBANHO_2014['EM_MD_caprino_GgCH4/municipio/2014'] = REBANHO_2014['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2014['EM_MD_muar_GgCH4/municipio/2014'] = REBANHO_2014['MUARES'] * 0.9 * 0.000001
REBANHO_2014['EM_MD_ovino_GgCH4/municipio/2014'] = REBANHO_2014['OVINOS'] * 0.15 * 0.000001
REBANHO_2014['EM_MD_asinino_GgCH4/municipio/2014'] = REBANHO_2014['ASININOS'] * 0.9 * 0.000001
REBANHO_2014['EM_MD_aves_GgCH4/municipio/2014'] = REBANHO_2014['AVES'] * 0.02 * 0.000001

REBANHO_2014
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2015 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2015]

REBANHO_2015['EM_MD_corte_GgCH4/municipio/2015'] = REBANHO_2015['CORTE'] * 0.96 * 0.000001
REBANHO_2015['EM_MD_leiteira_GgCH4/municipio/2015'] = REBANHO_2015['VACAS'] * 6.62 * 0.000001
REBANHO_2015['EM_MD_suino_GgCH4/municipio/2015'] = REBANHO_2015['SUINOS'] * 6.877 * 0.000001

REBANHO_2015['EM_MD_equino_GgCH4/municipio/2015'] = REBANHO_2015['EQUINO'] * 1.64 * 0.000001
REBANHO_2015['EM_MD_bubalino_GgCH4/municipio/2015'] = REBANHO_2015['BUBALINOS'] * 1 * 0.000001
REBANHO_2015['EM_MD_caprino_GgCH4/municipio/2015'] = REBANHO_2015['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2015['EM_MD_muar_GgCH4/municipio/2015'] = REBANHO_2015['MUARES'] * 0.9 * 0.000001
REBANHO_2015['EM_MD_ovino_GgCH4/municipio/2015'] = REBANHO_2015['OVINOS'] * 0.15 * 0.000001
REBANHO_2015['EM_MD_asinino_GgCH4/municipio/2015'] = REBANHO_2015['ASININOS'] * 0.9 * 0.000001
REBANHO_2015['EM_MD_aves_GgCH4/municipio/2015'] = REBANHO_2015['AVES'] * 0.02 * 0.000001

REBANHO_2015
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2016 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2016]

REBANHO_2016['EM_MD_corte_GgCH4/municipio/2016'] = REBANHO_2016['CORTE'] * 0.96 * 0.000001
REBANHO_2016['EM_MD_leiteira_GgCH4/municipio/2016'] = REBANHO_2016['VACAS'] * 7.13 * 0.000001
REBANHO_2016['EM_MD_suino_GgCH4/municipio/2016'] = REBANHO_2016['SUINOS'] * 7.177 * 0.000001

REBANHO_2016['EM_MD_equino_GgCH4/municipio/2016'] = REBANHO_2016['EQUINO'] * 1.64 * 0.000001
REBANHO_2016['EM_MD_bubalino_GgCH4/municipio/2016'] = REBANHO_2016['BUBALINOS'] * 1 * 0.000001
REBANHO_2016['EM_MD_caprino_GgCH4/municipio/2016'] = REBANHO_2016['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2016['EM_MD_muar_GgCH4/municipio/2016'] = REBANHO_2016['MUARES'] * 0.9 * 0.000001
REBANHO_2016['EM_MD_ovino_GgCH4/municipio/2016'] = REBANHO_2016['OVINOS'] * 0.15 * 0.000001
REBANHO_2016['EM_MD_asinino_GgCH4/municipio/2016'] = REBANHO_2016['ASININOS'] * 0.9 * 0.000001
REBANHO_2016['EM_MD_aves_GgCH4/municipio/2016'] = REBANHO_2016['AVES'] * 0.02 * 0.000001

REBANHO_2016
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2017 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2017]

REBANHO_2017['EM_MD_corte_GgCH4/municipio/2017'] = REBANHO_2017['CORTE'] * 0.96 * 0.000001
REBANHO_2017['EM_MD_leiteira_GgCH4/municipio/2017'] = REBANHO_2017['VACAS'] * 7.13 * 0.000001
REBANHO_2017['EM_MD_suino_GgCH4/municipio/2017'] = REBANHO_2017['SUINOS'] * 6.808 * 0.000001

REBANHO_2017['EM_MD_equino_GgCH4/municipio/2017'] = REBANHO_2017['EQUINO'] * 1.64 * 0.000001
REBANHO_2017['EM_MD_bubalino_GgCH4/municipio/2017'] = REBANHO_2017['BUBALINOS'] * 1 * 0.000001
REBANHO_2017['EM_MD_caprino_GgCH4/municipio/2017'] = REBANHO_2017['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2017['EM_MD_muar_GgCH4/municipio/2017'] = REBANHO_2017['MUARES'] * 0.9 * 0.000001
REBANHO_2017['EM_MD_ovino_GgCH4/municipio/2017'] = REBANHO_2017['OVINOS'] * 0.15 * 0.000001
REBANHO_2017['EM_MD_asinino_GgCH4/municipio/2017'] = REBANHO_2017['ASININOS'] * 0.9 * 0.000001
REBANHO_2017['EM_MD_aves_GgCH4/municipio/2017'] = REBANHO_2017['AVES'] * 0.02 * 0.000001

REBANHO_2017
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2018 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2018]

REBANHO_2018['EM_MD_corte_GgCH4/municipio/2018'] = REBANHO_2018['CORTE'] * 0.96 * 0.000001
REBANHO_2018['EM_MD_leiteira_GgCH4/municipio/2018'] = REBANHO_2018['VACAS'] * 7.13 * 0.000001
REBANHO_2018['EM_MD_suino_GgCH4/municipio/2018'] = REBANHO_2018['SUINOS'] * 6.808 * 0.000001

REBANHO_2018['EM_MD_equino_GgCH4/municipio/2018'] = REBANHO_2018['EQUINO'] * 1.64 * 0.000001
REBANHO_2018['EM_MD_bubalino_GgCH4/municipio/2018'] = REBANHO_2018['BUBALINOS'] * 1 * 0.000001
REBANHO_2018['EM_MD_caprino_GgCH4/municipio/2018'] = REBANHO_2018['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2018['EM_MD_muar_GgCH4/municipio/2018'] = REBANHO_2018['MUARES'] * 0.9 * 0.000001
REBANHO_2018['EM_MD_ovino_GgCH4/municipio/2018'] = REBANHO_2018['OVINOS'] * 0.15 * 0.000001
REBANHO_2018['EM_MD_asinino_GgCH4/municipio/2018'] = REBANHO_2018['ASININOS'] * 0.9 * 0.000001
REBANHO_2018['EM_MD_aves_GgCH4/municipio/2018'] = REBANHO_2018['AVES'] * 0.02 * 0.000001

REBANHO_2018
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
REBANHO_2019 = REBANHO_TODOS_ANO_TODOS.loc[REBANHO_TODOS_ANO_TODOS['Ano'] == 2019]

REBANHO_2019['EM_MD_corte_GgCH4/municipio/2019'] = REBANHO_2019['CORTE'] * 0.96 * 0.000001
REBANHO_2019['EM_MD_leiteira_GgCH4/municipio/2019'] = REBANHO_2019['VACAS'] * 7.13 * 0.000001
REBANHO_2019['EM_MD_suino_GgCH4/municipio/2019'] = REBANHO_2019['SUINOS'] * 6.808 * 0.000001

REBANHO_2019['EM_MD_equino_GgCH4/municipio/2019'] = REBANHO_2019['EQUINO'] * 1.64 * 0.000001
REBANHO_2019['EM_MD_bubalino_GgCH4/municipio/2019'] = REBANHO_2019['BUBALINOS'] * 1 * 0.000001
REBANHO_2019['EM_MD_caprino_GgCH4/municipio/2019'] = REBANHO_2019['CAPRINOS'] * 0.17 * 0.000001
REBANHO_2019['EM_MD_muar_GgCH4/municipio/2019'] = REBANHO_2019['MUARES'] * 0.9 * 0.000001
REBANHO_2019['EM_MD_ovino_GgCH4/municipio/2019'] = REBANHO_2019['OVINOS'] * 0.15 * 0.000001
REBANHO_2019['EM_MD_asinino_GgCH4/municipio/2019'] = REBANHO_2019['ASININOS'] * 0.9 * 0.000001
REBANHO_2019['EM_MD_aves_GgCH4/municipio/2019'] = REBANHO_2019['AVES'] * 0.02 * 0.000001

REBANHO_2019
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### SUPER MERGE PARA GERAR ARQUIVO DAS EMISSÕES ANUAIS DO MANEJO DE DEJETOS

# %%
# compile the list of dataframes you want to merge
data_frames = [REBANHO_2005, REBANHO_2006, REBANHO_2007,REBANHO_2008,REBANHO_2009,REBANHO_2010,REBANHO_2011,REBANHO_2012,REBANHO_2013,REBANHO_2014,REBANHO_2015,REBANHO_2016,REBANHO_2017,REBANHO_2018,REBANHO_2019]

# %%
from functools import reduce

# %%
df_merged = reduce(lambda left,right: pd.merge(left,right,on=['cd'], how='outer'), data_frames)

# %%
df_merged
# Out:
#          Ano_x  ...  EM_MD_aves_GgCH4/municipio/2019
# cd              ...
# 4100103   2005  ...                         0.007708
# 4100202   2005  ...                         0.000424
# 4100301   2005  ...                         0.001200
# 4100400   2005  ...                         0.000813
# 4100459   2005  ...                         0.004360
# ...        ...  ...                              ...
# 4128609   2005  ...                         0.046203
# 4128658   2005  ...                         0.000170
# 4128708   2005  ...                         0.003039
# 4128500   2005  ...                         0.008122
# 4128807   2005  ...                         0.002201
#
# [399 rows x 345 columns]

# %%
df_merged_reviewed = df_merged[['EM_MD_corte_GgCH4/municipio/2005','EM_MD_leiteira_GgCH4/municipio/2005','EM_MD_equino_GgCH4/municipio/2005','EM_MD_suino_GgCH4/municipio/2005','EM_MD_bubalino_GgCH4/municipio/2005','EM_MD_caprino_GgCH4/municipio/2005','EM_MD_muar_GgCH4/municipio/2005','EM_MD_ovino_GgCH4/municipio/2005','EM_MD_asinino_GgCH4/municipio/2005','EM_MD_corte_GgCH4/municipio/2006','EM_MD_leiteira_GgCH4/municipio/2006','EM_MD_equino_GgCH4/municipio/2006','EM_MD_suino_GgCH4/municipio/2006','EM_MD_bubalino_GgCH4/municipio/2006','EM_MD_caprino_GgCH4/municipio/2006','EM_MD_muar_GgCH4/municipio/2006','EM_MD_ovino_GgCH4/municipio/2006','EM_MD_asinino_GgCH4/municipio/2006','EM_MD_corte_GgCH4/municipio/2007','EM_MD_leiteira_GgCH4/municipio/2007','EM_MD_equino_GgCH4/municipio/2007','EM_MD_suino_GgCH4/municipio/2007','EM_MD_bubalino_GgCH4/municipio/2007','EM_MD_caprino_GgCH4/municipio/2007','EM_MD_muar_GgCH4/municipio/2007','EM_MD_ovino_GgCH4/municipio/2007','EM_MD_asinino_GgCH4/municipio/2007','EM_MD_corte_GgCH4/municipio/2008','EM_MD_leiteira_GgCH4/municipio/2008','EM_MD_equino_GgCH4/municipio/2008','EM_MD_suino_GgCH4/municipio/2008','EM_MD_bubalino_GgCH4/municipio/2008','EM_MD_caprino_GgCH4/municipio/2008','EM_MD_muar_GgCH4/municipio/2008','EM_MD_ovino_GgCH4/municipio/2008','EM_MD_asinino_GgCH4/municipio/2008','EM_MD_corte_GgCH4/municipio/2009','EM_MD_leiteira_GgCH4/municipio/2009','EM_MD_equino_GgCH4/municipio/2009','EM_MD_suino_GgCH4/municipio/2009','EM_MD_bubalino_GgCH4/municipio/2009','EM_MD_caprino_GgCH4/municipio/2009','EM_MD_muar_GgCH4/municipio/2009','EM_MD_ovino_GgCH4/municipio/2009','EM_MD_asinino_GgCH4/municipio/2009','EM_MD_corte_GgCH4/municipio/2010','EM_MD_leiteira_GgCH4/municipio/2010','EM_MD_equino_GgCH4/municipio/2010','EM_MD_suino_GgCH4/municipio/2010','EM_MD_bubalino_GgCH4/municipio/2010','EM_MD_caprino_GgCH4/municipio/2010','EM_MD_muar_GgCH4/municipio/2010','EM_MD_ovino_GgCH4/municipio/2010','EM_MD_asinino_GgCH4/municipio/2010','EM_MD_corte_GgCH4/municipio/2011','EM_MD_leiteira_GgCH4/municipio/2011','EM_MD_equino_GgCH4/municipio/2011','EM_MD_suino_GgCH4/municipio/2011','EM_MD_bubalino_GgCH4/municipio/2011','EM_MD_caprino_GgCH4/municipio/2011','EM_MD_muar_GgCH4/municipio/2011','EM_MD_ovino_GgCH4/municipio/2011','EM_MD_asinino_GgCH4/municipio/2011','EM_MD_corte_GgCH4/municipio/2012','EM_MD_leiteira_GgCH4/municipio/2012','EM_MD_equino_GgCH4/municipio/2012','EM_MD_suino_GgCH4/municipio/2012','EM_MD_bubalino_GgCH4/municipio/2012','EM_MD_caprino_GgCH4/municipio/2012','EM_MD_muar_GgCH4/municipio/2012','EM_MD_ovino_GgCH4/municipio/2012','EM_MD_asinino_GgCH4/municipio/2012','EM_MD_corte_GgCH4/municipio/2013','EM_MD_leiteira_GgCH4/municipio/2013','EM_MD_equino_GgCH4/municipio/2013','EM_MD_suino_GgCH4/municipio/2013','EM_MD_bubalino_GgCH4/municipio/2013','EM_MD_caprino_GgCH4/municipio/2013','EM_MD_muar_GgCH4/municipio/2013','EM_MD_ovino_GgCH4/municipio/2013','EM_MD_asinino_GgCH4/municipio/2013','EM_MD_corte_GgCH4/municipio/2014','EM_MD_leiteira_GgCH4/municipio/2014','EM_MD_equino_GgCH4/municipio/2014','EM_MD_suino_GgCH4/municipio/2014','EM_MD_bubalino_GgCH4/municipio/2014','EM_MD_caprino_GgCH4/municipio/2014','EM_MD_muar_GgCH4/municipio/2014','EM_MD_ovino_GgCH4/municipio/2014','EM_MD_asinino_GgCH4/municipio/2014','EM_MD_corte_GgCH4/municipio/2015','EM_MD_leiteira_GgCH4/municipio/2015','EM_MD_equino_GgCH4/municipio/2015','EM_MD_suino_GgCH4/municipio/2015','EM_MD_bubalino_GgCH4/municipio/2015','EM_MD_caprino_GgCH4/municipio/2015','EM_MD_muar_GgCH4/municipio/2015','EM_MD_ovino_GgCH4/municipio/2015','EM_MD_asinino_GgCH4/municipio/2015','EM_MD_corte_GgCH4/municipio/2016','EM_MD_leiteira_GgCH4/municipio/2016','EM_MD_equino_GgCH4/municipio/2016','EM_MD_suino_GgCH4/municipio/2016','EM_MD_bubalino_GgCH4/municipio/2016','EM_MD_caprino_GgCH4/municipio/2016','EM_MD_muar_GgCH4/municipio/2016','EM_MD_ovino_GgCH4/municipio/2016','EM_MD_asinino_GgCH4/municipio/2016','EM_MD_corte_GgCH4/municipio/2017','EM_MD_leiteira_GgCH4/municipio/2017','EM_MD_equino_GgCH4/municipio/2017','EM_MD_suino_GgCH4/municipio/2017','EM_MD_bubalino_GgCH4/municipio/2017','EM_MD_caprino_GgCH4/municipio/2017','EM_MD_muar_GgCH4/municipio/2017','EM_MD_ovino_GgCH4/municipio/2017','EM_MD_asinino_GgCH4/municipio/2017','EM_MD_corte_GgCH4/municipio/2018','EM_MD_leiteira_GgCH4/municipio/2018','EM_MD_equino_GgCH4/municipio/2018','EM_MD_suino_GgCH4/municipio/2018','EM_MD_bubalino_GgCH4/municipio/2018','EM_MD_caprino_GgCH4/municipio/2018','EM_MD_muar_GgCH4/municipio/2018','EM_MD_ovino_GgCH4/municipio/2018','EM_MD_asinino_GgCH4/municipio/2018','EM_MD_corte_GgCH4/municipio/2019','EM_MD_leiteira_GgCH4/municipio/2019','EM_MD_equino_GgCH4/municipio/2019','EM_MD_suino_GgCH4/municipio/2019','EM_MD_bubalino_GgCH4/municipio/2019','EM_MD_caprino_GgCH4/municipio/2019','EM_MD_muar_GgCH4/municipio/2019','EM_MD_ovino_GgCH4/municipio/2019','EM_MD_asinino_GgCH4/municipio/2019','EM_MD_aves_GgCH4/municipio/2005','EM_MD_aves_GgCH4/municipio/2006','EM_MD_aves_GgCH4/municipio/2007','EM_MD_aves_GgCH4/municipio/2008','EM_MD_aves_GgCH4/municipio/2009','EM_MD_aves_GgCH4/municipio/2010','EM_MD_aves_GgCH4/municipio/2011','EM_MD_aves_GgCH4/municipio/2012','EM_MD_aves_GgCH4/municipio/2013','EM_MD_aves_GgCH4/municipio/2014','EM_MD_aves_GgCH4/municipio/2015','EM_MD_aves_GgCH4/municipio/2016','EM_MD_aves_GgCH4/municipio/2017','EM_MD_aves_GgCH4/municipio/2018','EM_MD_aves_GgCH4/municipio/2019']]
df_merged_reviewed
# Out:
#          EM_MD_corte_GgCH4/municipio/2005  ...  EM_MD_aves_GgCH4/municipio/2019
# cd                                         ...
# 4100103                          0.015977  ...                         0.007708
# 4100202                          0.016470  ...                         0.000424
# 4100301                          0.001738  ...                         0.001200
# 4100400                          0.001000  ...                         0.000813
# 4100459                          0.050884  ...                         0.004360
# ...                                   ...  ...                              ...
# 4128609                          0.020913  ...                         0.046203
# 4128658                          0.008001  ...                         0.000170
# 4128708                          0.011186  ...                         0.003039
# 4128500                          0.024232  ...                         0.008122
# ...

# %%
### adicionando coluna de somatório de emissão de todos os rebanhos por ano 

df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2005'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2005'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2005'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2006'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2006'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2006'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2007'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2007'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2007'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2008'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2008'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2008'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2009'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2009'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2009'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2010'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2010'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2010'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2011'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2011'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2011'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2012'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2012'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2012'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2013'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2013'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2013'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2014'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2014'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2014'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2015'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2015'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2015'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2016'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2016'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2016'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2017'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2017'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2017'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2018'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2018'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2018'] 
df_merged_reviewed['EM_MD_todos_GgCH4/municipio/2019'] = df_merged_reviewed['EM_MD_corte_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_leiteira_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_equino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_suino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_bubalino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_caprino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_muar_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_ovino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_asinino_GgCH4/municipio/2019'] + df_merged_reviewed['EM_MD_aves_GgCH4/municipio/2019'] 

df_merged_reviewed
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
df_merged_reviewed.describe()
# Out:
#        EM_MD_corte_GgCH4/municipio/2005  ...  EM_MD_todos_GgCH4/municipio/2019
# count                        399.000000  ...                        399.000000
# mean                           0.023356  ...                          0.179511
# std                            0.023657  ...                          0.509989
# min                            0.000027  ...                          0.000353
# 25%                            0.007912  ...                          0.032693
# 50%                            0.016455  ...                          0.069857
# 75%                            0.030453  ...                          0.151499
# max                            0.201572  ...                          8.293772
#
# [8 rows x 165 columns]

# %%
df_merged_reviewed.sum()
# Out:
# EM_MD_corte_GgCH4/municipio/2005        9.319116
# EM_MD_leiteira_GgCH4/municipio/2005     6.904103
# EM_MD_equino_GgCH4/municipio/2005       0.698647
# EM_MD_suino_GgCH4/municipio/2005       18.355304
# EM_MD_bubalino_GgCH4/municipio/2005     0.040187
#                                          ...
# EM_MD_todos_GgCH4/municipio/2015       74.427280
# EM_MD_todos_GgCH4/municipio/2016       77.155576
# EM_MD_todos_GgCH4/municipio/2017       72.526568
# EM_MD_todos_GgCH4/municipio/2018       72.494805
# EM_MD_todos_GgCH4/municipio/2019       71.624723
# Length: 165, dtype: float64

# %%
cdibge = pd.read_csv('https://www.dropbox.com/s/khnf2k1eyeqa1av/IBGE_cd_mun.csv?dl=1')
cdibge.head()
# Out:
#         cd                  mun
# 0  4100103               Abatiá
# 1  4100202         Adrianópolis
# 2  4100301        Agudos do Sul
# 3  4100400  Almirante Tamandaré
# 4  4100459   Altamira do Paraná

# %%
cdibge = cdibge.set_index('cd')

# %%
df_merged_reviewed = pd.merge(cdibge,df_merged_reviewed, on='cd')

# %%
df_merged_reviewed
# Out:
#                          mun  ...  EM_MD_todos_GgCH4/municipio/2019
# cd                            ...
# 4100103               Abatiá  ...                          0.033068
# 4100202         Adrianópolis  ...                          0.033246
# 4100301        Agudos do Sul  ...                          0.024815
# 4100400  Almirante Tamandaré  ...                          0.024165
# 4100459   Altamira do Paraná  ...                          0.101025
# ...                      ...  ...                               ...
# 4128609                 Verê  ...                          0.172181
# 4128658              Virmond  ...                          0.112952
# 4128708             Vitorino  ...                          0.124663
# 4128500       Wenceslau Braz  ...                          0.081050
# 4128807               Xambrê  ...                          0.082103
#
# [399 rows x 166 columns]

# %%
from google.colab import files
df_merged_reviewed.to_csv('EMISSOES_ANUAIS_MD_tipo_rebanho.csv', sep = ";")
files.download('EMISSOES_ANUAIS_MD_tipo_rebanho.csv')

# %%
df_merged.sum()
# Out:
# Ano_x                                 7.999950e+05
# CORTE_x                               8.791619e+06
# EQUINO_x                              4.260040e+05
# GALINACEOS_x                          1.716540e+08
# CODORNAS_x                            4.945060e+05
#                                           ...
# EM_MD_caprino_GgCH4/municipio/2019    1.752428e-02
# EM_MD_muar_GgCH4/municipio/2019       0.000000e+00
# EM_MD_ovino_GgCH4/municipio/2019      8.834940e-02
# EM_MD_asinino_GgCH4/municipio/2019    0.000000e+00
# EM_MD_aves_GgCH4/municipio/2019       7.795882e+00
# Length: 345, dtype: float64

# %%
EMISSOES_ANUAIS_MANEJO_DEJETOS = df_merged_reviewed[["mun","EM_MD_todos_GgCH4/municipio/2005","EM_MD_todos_GgCH4/municipio/2006","EM_MD_todos_GgCH4/municipio/2007","EM_MD_todos_GgCH4/municipio/2008","EM_MD_todos_GgCH4/municipio/2009","EM_MD_todos_GgCH4/municipio/2010","EM_MD_todos_GgCH4/municipio/2011","EM_MD_todos_GgCH4/municipio/2012","EM_MD_todos_GgCH4/municipio/2013","EM_MD_todos_GgCH4/municipio/2014","EM_MD_todos_GgCH4/municipio/2015","EM_MD_todos_GgCH4/municipio/2016","EM_MD_todos_GgCH4/municipio/2017","EM_MD_todos_GgCH4/municipio/2018","EM_MD_todos_GgCH4/municipio/2019"]]
EMISSOES_ANUAIS_MANEJO_DEJETOS
# Out:
#                          mun  ...  EM_MD_todos_GgCH4/municipio/2019
# cd                            ...
# 4100103               Abatiá  ...                          0.033068
# 4100202         Adrianópolis  ...                          0.033246
# 4100301        Agudos do Sul  ...                          0.024815
# 4100400  Almirante Tamandaré  ...                          0.024165
# 4100459   Altamira do Paraná  ...                          0.101025
# ...                      ...  ...                               ...
# 4128609                 Verê  ...                          0.172181
# 4128658              Virmond  ...                          0.112952
# 4128708             Vitorino  ...                          0.124663
# 4128500       Wenceslau Braz  ...                          0.081050
# 4128807               Xambrê  ...                          0.082103
#
# [399 rows x 16 columns]

# %%
from google.colab import files
EMISSOES_ANUAIS_MANEJO_DEJETOS.to_csv('EMISSOES_ANUAIS_MANEJO_DEJETOS.csv', sep = ";")
files.download('EMISSOES_ANUAIS_MANEJO_DEJETOS.csv')

# %% [markdown]
# ## Resumo estatístico - AFOLU - Fermentação entérica e manejo de dejetos

# %%
estatistica_EMISSOES_ANUAIS_FERMENTACAO_ENTERICA = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA.describe()
estatistica_EMISSOES_ANUAIS_FERMENTACAO_ENTERICA
# Out:
#        EM_F.ENT_TOTAL_2005  ...  EM_F.ENT_TOTAL_2019_GgCO2E_GTP
# count           399.000000  ...                      399.000000
# mean              1.513350  ...                        5.388260
# std               1.409510  ...                        5.572348
# min               0.008769  ...                        0.014878
# 25%               0.550374  ...                        1.493081
# 50%               1.139236  ...                        3.527640
# 75%               2.037130  ...                        7.455239
# max              11.898913  ...                       35.413646
#
# [8 rows x 45 columns]

# %%
estatistica_EMISSOES_ANUAIS_FERMENTACAO_ENTERICA.sum()
# Out:
# EM_F.ENT_TOTAL_2005               417.557282
# EM_F.ENT_TOTAL_2006               416.257079
# EM_F.ENT_TOTAL_2007               415.415196
# EM_F.ENT_TOTAL_2008               415.107531
# EM_F.ENT_TOTAL_2009               414.650352
# EM_F.ENT_TOTAL_2010               413.779953
# EM_F.ENT_TOTAL_2011               414.140505
# EM_F.ENT_TOTAL_2012               413.524456
# EM_F.ENT_TOTAL_2013               414.558821
# EM_F.ENT_TOTAL_2014               414.062330
# EM_F.ENT_TOTAL_2015               414.224811
# EM_F.ENT_TOTAL_2016               414.737463
# EM_F.ENT_TOTAL_2017               414.534633
# EM_F.ENT_TOTAL_2018               414.377001
# EM_F.ENT_TOTAL_2019               413.716273
# EM_F.ENT_TOTAL_2005_GgCO2E_GWP    918.603898
# EM_F.ENT_TOTAL_2006_GgCO2E_GWP    882.198221
# EM_F.ENT_TOTAL_2007_GgCO2E_GWP    858.625490
# EM_F.ENT_TOTAL_2008_GgCO2E_GWP    850.010857
# EM_F.ENT_TOTAL_2009_GgCO2E_GWP    837.209860
# EM_F.ENT_TOTAL_2010_GgCO2E_GWP    812.838681
# ...

# %%
estatistica_EMISSOES_ANUAIS_MANEJO_DEJETOS = EMISSOES_ANUAIS_MANEJO_DEJETOS.describe()
estatistica_EMISSOES_ANUAIS_MANEJO_DEJETOS
# Out:
#        EM_MD_TOTAL_2005  ...  EM_MD_TOTAL_2019_GgCO2E_GTP
# count        399.000000  ...                   399.000000
# mean           0.082824  ...                     0.406940
# std            0.117102  ...                     1.175009
# min            0.000935  ...                     0.000828
# 25%            0.027605  ...                     0.067910
# 50%            0.053957  ...                     0.159860
# 75%            0.099696  ...                     0.341681
# max            1.649245  ...                    19.284655
#
# [8 rows x 45 columns]

# %%
estatistica_EMISSOES_ANUAIS_MANEJO_DEJETOS.sum()
# Out:
# EM_MD_TOTAL_2005               401.031365
# EM_MD_TOTAL_2006               401.099007
# EM_MD_TOTAL_2007               401.140155
# EM_MD_TOTAL_2008               401.124400
# EM_MD_TOTAL_2009               401.491856
# EM_MD_TOTAL_2010               401.465261
# EM_MD_TOTAL_2011               401.339158
# EM_MD_TOTAL_2012               401.712989
# EM_MD_TOTAL_2013               401.266295
# EM_MD_TOTAL_2014               402.434953
# EM_MD_TOTAL_2015               404.683616
# EM_MD_TOTAL_2016               404.430412
# EM_MD_TOTAL_2017               404.408428
# EM_MD_TOTAL_2018               404.364179
# EM_MD_TOTAL_2019               404.359221
# EM_MD_TOTAL_2005_GgCO2E_GWP    455.878215
# EM_MD_TOTAL_2006_GgCO2E_GWP    457.772201
# EM_MD_TOTAL_2007_GgCO2E_GWP    458.924335
# EM_MD_TOTAL_2008_GgCO2E_GWP    458.483202
# EM_MD_TOTAL_2009_GgCO2E_GWP    468.771973
# EM_MD_TOTAL_2010_GgCO2E_GWP    468.027302
# EM_MD_TOTAL_2011_GgCO2E_GWP    464.496425
# ...

# %% [markdown]
# ### Calculos das emissão para o método GWP (metano = 28x) e GTP (metano = 4x)

# %%
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2005_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2005']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2006_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2006']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2007_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2007']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2008_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2008']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2009_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2009']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2010_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2010']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2011_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2011']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2012_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2012']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2013_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2013']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2014_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2014']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2015_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2015']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2016_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2016']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2017_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2017']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2018_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2018']*28
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2019_GgCO2E_GWP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2019']*28
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EM_F.ENT_TOTAL_2005'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-3802b7f09844> in <module>()
# ...

# %%
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2005_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2005']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2006_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2006']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2007_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2007']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2008_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2008']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2009_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2009']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2010_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2010']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2011_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2011']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2012_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2012']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2013_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2013']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2014_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2014']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2015_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2015']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2016_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2016']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2017_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2017']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2018_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2018']*4
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2019_GgCO2E_GTP'] = EMISSOES_ANUAIS_FERMENTACAO_ENTERICA['EM_F.ENT_TOTAL_2019']*4

# %%
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA.sum()

# %%
EMISSOES_ANUAIS_FERMENTACAO_ENTERICA
